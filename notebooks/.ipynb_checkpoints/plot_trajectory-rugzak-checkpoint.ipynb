# %%
import sys
sys.path.append('..')
import os
os.environ['STEREO_CONFIDENCE'] = '1.8'
os.environ['SEQUENCE_CONFIDENCE'] = '1.8'
os.environ['PATCH_SIZE'] = '17'
from progressbar import ProgressBar
from pyurb.urb_zed import *
import cv2
# %matplotlib inline

# %% [markdown]
# Read frames from KITTI sequence 00 into a list of frames (frame).

# %%
bar = ProgressBar()
LEFTDIR = '/data/urbinn/datasets/slinger_rugzak_2017-11-02/left'
RIGHTDIR = '/data/urbinn/datasets/slinger_rugzak_2017-11-02/right'

seq = Sequence()
for frameid in bar(range(1, 100)):
    filename = '%06d.png'%(frameid)
    left_frame = Frame(LEFTDIR + '/' + filename, RIGHTDIR)
    seq.add_frame(left_frame, clean=True)
# Out:
#   1% (1 of 99) |                          | Elapsed Time: 0:00:02 ETA:  0:03:22
# invalid speed 0.256778346858 0.256778346858
#  [[ 0.99549535 -0.01979261  0.09272141  0.05487349]
#  [-0.0041876   0.96783352  0.25155665  0.03818578]
#  [-0.09471785 -0.25081176  0.96339088  0.25677835]
#  [ 0.          0.          0.          1.        ]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-6da56354da24> in <module>()
#       7     filename = '%06d.png'%(frameid)
#       8     left_frame = Frame(LEFTDIR + '/' + filename, RIGHTDIR)
# ----> 9     seq.add_frame(left_frame, clean=True)
#
# /home/jeroen/notebooks/pyurb/pyurb/urb_sequence.py in add_frame(self, frame, sequence_confidence, clean)
#      87                         f.clean()
#      88                     keyframe.clean()
# ---> 89                 keyframe = keyframe.frames.pop()
#      90                 self.add_keyframe( keyframe )
#      91                 last_z = keyframe.frames[-1].get_pose()[2, 3] if len(keyframe.frames) > 0 else 0
#
# IndexError: pop from empty list

# %%
show(draw_frame_depth(seq.keyframes[0]))

# %%
left_frame.compute_depth()
left_frame.filter_not_useful()
show(draw_frame_depth(left_frame))

# %%
trajectoryXZ = []
points = []

for frame in seq.keyframes[:]:
    pose = frame.get_pose()
    if pose is not None:
        points_new = []
        for p in points:
            p = np.dot(pose, p)
            points_new.append(p)
        points = points_new
        new_point = np.array([0,0,0,1.0])
        points.append(new_point)
  

minx = min([p[0] for p in points])
maxx = max([p[0] for p in points])
miny = min([p[2] for p in points])
maxy = max([p[2] for p in points])
maxxy = max(maxx, maxy)


for p in points:
    #print(p)
    x = 400 * (p[0] - minx) / (maxxy)
    z = 400 * (p[2] - miny) / (maxxy)
    trajectoryXZ.append([x, z])

# %%
# Create a blank image
img = np.zeros((400, 400, 3), np.uint8) 
img[:] = 255 #or img.fill(255)

# Draw a black line with thickness of 2 px
for i in range(1,len(trajectoryXZ)):
    cv2.line(img, (int(trajectoryXZ[i - 1][0]), int(trajectoryXZ[i - 1][1])), (int(trajectoryXZ[i][0]), int(trajectoryXZ[i][1])), (0, 0, 0), 1)
show(img)

# %%
a = type(seq.keyframes[0])
a.__name__

# %%
import urb_json
s = urb_json.saves(seq.keyframes[0])

# %%
s

# %%
r = urb_json.loads(s)
